# %%
# """
# View more, visit my tutorial page: https://morvanzhou.github.io/tutorials/
# My Youtube Channel: https://www.youtube.com/user/MorvanZhou
# More about Reinforcement learning: https://morvanzhou.github.io/tutorials/machine-learning/reinforcement-learning/
# Dependencies:
# torch: 0.4
# gym: 0.8.1
# numpy
# """

# %%
# %matplotlib inline
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gym
import matplotlib.pyplot as plt

# %%
seed = 161
# random.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
# os.environ['PYTHONHASHSEED'] = str(seed)

# %%
# Hyper Parameters
BATCH_SIZE = 32
LR = 1e-2                  # learning rate
EPSILON = 0.9               # greedy policy
GAMMA = 0.9                 # reward discount
TARGET_REPLACE_ITER = 100   # target update frequency
MEMORY_CAPACITY = 2000

# %%
env = gym.make('CartPole-v0')
env = env.unwrapped
env.seed(seed);

# %%
N_ACTIONS = env.action_space.n
N_STATES = env.observation_space.shape[0]
ENV_A_SHAPE = 0 if isinstance(env.action_space.sample(), int) else env.action_space.sample().shape     # to confirm the shape

# %%
class Net(nn.Module):
    def __init__(self, ):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(N_STATES, 50)
        nn.init.kaiming_uniform_(self.fc1.weight)   # initialization
        self.out = nn.Linear(50, N_ACTIONS)
        nn.init.xavier_uniform_(self.out.weight)   # initialization

    def forward(self, x):
        x = self.fc1(x)
        x = F.relu(x)
        actions_value = self.out(x)
        return actions_value

# %%
class DQN(object):
    def __init__(self):
        self.eval_net, self.target_net = Net(), Net()
#         print("Neural net")
#         print(self.eval_net)

        self.learn_step_counter = 0                                     # for target updating
        self.memory_counter = 0                                         # for storing memory
        self.memory = np.zeros((MEMORY_CAPACITY, N_STATES * 2 + 2))     # initialize memory
        self.optimizer = torch.optim.Adam(self.eval_net.parameters(), lr=LR)
        self.loss_func = nn.MSELoss()

    def choose_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        if np.random.uniform() < EPSILON:   # greedy
            actions_value = self.eval_net.forward(x)
            action = torch.max(actions_value, 1)[1].data.numpy()
            action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        else:   # random
            action = np.random.randint(0, N_ACTIONS)
            action = action if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)
        return action
    
    def choose_greedy_action(self, x):
        x = torch.unsqueeze(torch.FloatTensor(x), 0)
        # input only one sample
        actions_value = self.eval_net.forward(x)
        action = torch.max(actions_value, 1)[1].data.numpy()
        action = action[0] if ENV_A_SHAPE == 0 else action.reshape(ENV_A_SHAPE)  # return the argmax index
        return action

    def store_transition(self, s, a, r, s_):
        transition = np.hstack((s, [a, r], s_))
        # replace the old memory with new memory
        index = self.memory_counter % MEMORY_CAPACITY
        self.memory[index, :] = transition
        self.memory_counter += 1

    def learn(self):
        # target parameter update
        if self.learn_step_counter % TARGET_REPLACE_ITER == 0:
            self.target_net.load_state_dict(self.eval_net.state_dict())
        self.learn_step_counter += 1

        # sample batch transitions
        sample_index = np.random.choice(MEMORY_CAPACITY, BATCH_SIZE)
        b_memory = self.memory[sample_index, :]
        b_s = torch.FloatTensor(b_memory[:, :N_STATES])
        b_a = torch.LongTensor(b_memory[:, N_STATES:N_STATES+1].astype(int))
        b_r = torch.FloatTensor(b_memory[:, N_STATES+1:N_STATES+2])
        b_s_ = torch.FloatTensor(b_memory[:, -N_STATES:])

        # q_eval w.r.t the action in experience
        q_eval = self.eval_net(b_s).gather(1, b_a)  # shape (batch, 1)
        q_next = self.target_net(b_s_).detach()     # detach from graph, don't backpropagate
        q_target = b_r + GAMMA * q_next.max(1)[0].view(BATCH_SIZE, 1)   # shape (batch, 1)
        loss = self.loss_func(q_eval, q_target)

        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

# %%
dqn = DQN()
NO_OF_EPISODES = 1000

# %%
print('\nCollecting experience...')
ep_r_rec = []
time_rec = []
flag = True
learn_start = 0

for i_episode in range(NO_OF_EPISODES):

    s = env.reset()
    ep_r = 0
    time_steps = 0
    while True:
#         env.render()
        time_steps += 1
        a = dqn.choose_action(s)

        # take action
        s_, r, done, info = env.step(a)

        # modify the reward
        x, x_dot, theta, theta_dot = s_
        r1 = (env.x_threshold - abs(x)) / env.x_threshold - 0.8
        r2 = (env.theta_threshold_radians - abs(theta)) / env.theta_threshold_radians - 0.5
        r = r1 + r2

        dqn.store_transition(s, a, r, s_)
        ep_r += r
        if dqn.memory_counter > MEMORY_CAPACITY:
            dqn.learn()
            if flag:
                print("Learning starts from EPISODE: ",i_episode)
                flag = False
        if done:
            ep_r_rec = np.append(ep_r_rec, ep_r)
            time_rec = np.append(time_rec, time_steps)
            if time_steps > 2000:
                print('EPISODE: {:4d}  |  REWARD: {:10.3f}  | TIME_STEPS: {:5d} | LR: {:3.2e} | EPSILON: {:3.2f} '.format(i_episode, ep_r, time_steps, LR, EPSILON))
            break
        s = s_
# Out:
# Collecting experience...
# Learning starts from EPISODE:  197
# EPISODE:  227  |  REWARD:    836.962  | TIME_STEPS:  2165 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  236  |  REWARD:    697.435  | TIME_STEPS:  3108 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  239  |  REWARD:   1186.896  | TIME_STEPS:  3641 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  244  |  REWARD:   1166.906  | TIME_STEPS:  2700 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  247  |  REWARD:   1449.037  | TIME_STEPS:  3654 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  250  |  REWARD:     -7.087  | TIME_STEPS:  2400 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  251  |  REWARD:   1618.901  | TIME_STEPS:  3236 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  253  |  REWARD:    696.252  | TIME_STEPS:  2211 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  255  |  REWARD:    509.682  | TIME_STEPS:  2449 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  270  |  REWARD:   1080.655  | TIME_STEPS:  3283 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  275  |  REWARD:    869.376  | TIME_STEPS:  3023 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  280  |  REWARD:    568.459  | TIME_STEPS:  2006 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  282  |  REWARD:   1053.989  | TIME_STEPS:  2449 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  291  |  REWARD:   1004.165  | TIME_STEPS:  2775 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  296  |  REWARD:    259.794  | TIME_STEPS:  2656 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  298  |  REWARD:    795.057  | TIME_STEPS:  2221 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  301  |  REWARD:    665.494  | TIME_STEPS:  4524 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  309  |  REWARD:    943.433  | TIME_STEPS:  2544 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  310  |  REWARD:   1047.547  | TIME_STEPS:  2243 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  322  |  REWARD:    731.756  | TIME_STEPS:  4305 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  325  |  REWARD:   1179.408  | TIME_STEPS:  2803 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  326  |  REWARD:    456.220  | TIME_STEPS:  2670 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  328  |  REWARD:   1853.572  | TIME_STEPS:  4194 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  341  |  REWARD:   1313.950  | TIME_STEPS:  6250 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  348  |  REWARD:    499.751  | TIME_STEPS:  2232 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  351  |  REWARD:    556.132  | TIME_STEPS:  2386 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  353  |  REWARD:    994.299  | TIME_STEPS:  2042 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  356  |  REWARD:    395.228  | TIME_STEPS:  2295 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  365  |  REWARD:   1150.893  | TIME_STEPS:  2665 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  374  |  REWARD:    939.345  | TIME_STEPS:  2308 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  377  |  REWARD:    905.722  | TIME_STEPS:  2339 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  378  |  REWARD:    594.357  | TIME_STEPS:  2040 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  384  |  REWARD:   1376.369  | TIME_STEPS:  4709 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  398  |  REWARD:    745.085  | TIME_STEPS:  2151 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  414  |  REWARD:    589.335  | TIME_STEPS:  2296 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  415  |  REWARD:    848.633  | TIME_STEPS:  2096 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  421  |  REWARD:    628.219  | TIME_STEPS:  3320 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  423  |  REWARD:   1359.274  | TIME_STEPS:  3583 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  425  |  REWARD:    645.459  | TIME_STEPS:  2416 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  431  |  REWARD:    820.699  | TIME_STEPS:  3505 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  433  |  REWARD:   1393.176  | TIME_STEPS:  2741 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  435  |  REWARD:    550.481  | TIME_STEPS:  3420 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  444  |  REWARD:    909.318  | TIME_STEPS:  2262 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  461  |  REWARD:   1109.626  | TIME_STEPS:  3044 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  462  |  REWARD:   1492.499  | TIME_STEPS:  2862 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  466  |  REWARD:   1660.288  | TIME_STEPS:  4666 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  467  |  REWARD:   1309.319  | TIME_STEPS:  2924 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  469  |  REWARD:   2253.015  | TIME_STEPS:  4568 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  472  |  REWARD:    880.962  | TIME_STEPS:  2200 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  478  |  REWARD:    954.842  | TIME_STEPS:  2445 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:
| LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  740  |  REWARD:    596.065  | TIME_STEPS:  2139 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  744  |  REWARD:    984.846  | TIME_STEPS:  2244 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  745  |  REWARD:    673.073  | TIME_STEPS:  2086 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  747  |  REWARD:    588.362  | TIME_STEPS:  2100 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  749  |  REWARD:   1059.981  | TIME_STEPS:  2162 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  754  |  REWARD:   1237.437  | TIME_STEPS:  4543 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  757  |  REWARD:    944.405  | TIME_STEPS:  2658 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  759  |  REWARD:   1161.032  | TIME_STEPS:  2536 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  763  |  REWARD:   1242.462  | TIME_STEPS:  3998 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  770  |  REWARD:    737.438  | TIME_STEPS:  4000 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  788  |  REWARD:   1549.182  | TIME_STEPS:  2971 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  810  |  REWARD:   1323.729  | TIME_STEPS:  4272 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  813  |  REWARD:    693.049  | TIME_STEPS:  2446 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  816  |  REWARD:   1114.631  | TIME_STEPS:  2911 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  817  |  REWARD:    767.034  | TIME_STEPS:  2184 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  825  |  REWARD:   1059.293  | TIME_STEPS:  3822 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  826  |  REWARD:    426.820  | TIME_STEPS:  2786 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  827  |  REWARD:   1027.868  | TIME_STEPS:  2680 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  828  |  REWARD:   1196.963  | TIME_STEPS:  2973 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  841  |  REWARD:    402.265  | TIME_STEPS:  2402 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  844  |  REWARD:   1288.322  | TIME_STEPS:  3287 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  857  |  REWARD:    869.126  | TIME_STEPS:  2353 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  860  |  REWARD:    685.406  | TIME_STEPS:  2005 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  866  |  REWARD:    636.889  | TIME_STEPS:  3014 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  877  |  REWARD:    698.434  | TIME_STEPS:  3287 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  883  |  REWARD:   1732.765  | TIME_STEPS:  3277 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  899  |  REWARD:   1353.207  | TIME_STEPS:  2713 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  905  |  REWARD:    970.572  | TIME_STEPS:  3737 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  909  |  REWARD:   1125.881  | TIME_STEPS:  2428 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  911  |  REWARD:   1183.221  | TIME_STEPS:  2607 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  913  |  REWARD:    815.929  | TIME_STEPS:  2543 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  919  |  REWARD:    629.804  | TIME_STEPS:  2213 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  921  |  REWARD:   1282.198  | TIME_STEPS:  4065 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  926  |  REWARD:   1761.324  | TIME_STEPS:  3583 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  931  |  REWARD:    645.692  | TIME_STEPS:  2019 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  936  |  REWARD:    336.511  | TIME_STEPS:  3425 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  942  |  REWARD:    991.441  | TIME_STEPS:  2480 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  945  |  REWARD:   1153.443  | TIME_STEPS:  2529 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  948  |  REWARD:    308.115  | TIME_STEPS:  2475 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  959  |  REWARD:    885.932  | TIME_STEPS:  2384 | LR: 1.00e-02 | EPSILON: 0.90
# EPISODE:  978  |  REWARD:    947.463  | TIME_STEPS:  3081 | LR: 1.00e-02 | EPSILON: 0.90

# %%
fig = plt.figure(figsize = (15,6))

ax2 = fig.add_subplot(2, 1, 1)
data = time_rec[learn_start:]
ax2.plot(data, color = 'g')
ax2.plot(np.ones_like(data)*1500, 'g--')
ax2.plot(np.ones_like(data)*200, 'r--')

ax2.set_title('Time Steps',color = 'g')
for xpt in [250,500]:
    ax2.axvline(x=xpt,color='k',linewidth='0.8')
ax2.set_yscale('log')
ax2.set_ylim([1,1e4])
ax2.grid()

fig.tight_layout()
plt.show()

# %%
env.close()

# %%
# s = env.reset()
# while True:
#     env.render()
#     a = dqn.choose_greedy_action(s)
#     s_, r, done, info = env.step(a)
#     if done:
#         break
#     s = s_

# %%
# env.close()
